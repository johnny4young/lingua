// %% [markdown]
// # Mixed notebook
//
// Markdown + code, no outputs.

// %%
const greeting = 'hi';
console.log(greeting);

// %% [markdown]
// ## Section two

// %% [raw]
// This is a raw cell — should be dropped on import.

// %%
const followup = greeting.toUpperCase();
